# %%
import pandas as pd
import os
pd.set_option('display.max_colwidth', None)

# %%
path = os.path.abspath(os.path.join('..', 'input'))

# %%
output = os.path.abspath(os.path.join('..', 'output'))

# %% [markdown]
# ### Votação

# %%
path_tabela = os.path.join(path, 'votacoes-2023.xlsx')
df = pd.read_excel(path_tabela)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
path_tabela = os.path.join(path, 'votacoesObjetos-2022.xlsx')
df_objeto = pd.read_excel(path_tabela)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
path_tabela = os.path.join(path, 'votacoesOrientacoes-2023.xlsx')
df_orientacoes = pd.read_excel(path_tabela)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
path_tabela = os.path.join(path, 'votacoesProposicoes-2022.xlsx')
df_proposicoes = pd.read_excel(path_tabela)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
path_tabela = os.path.join(path, 'votacoesVotos-2023.xlsx')
df_votos = pd.read_excel(path_tabela)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# #### Orientação Bancada Votação

# %%
df_concatenado = pd.DataFrame()
path = r'C:\Users\User\Downloads\workspace\br_camera_deputados\input\orientacao_bancada_votacao'


# Loop pelos anos de 2003 a 2023
for ano in range(2003, 2024):
    # Crie o caminho para o arquivo Excel correspondente ao ano
    arquivo_excel = f'votacoesOrientacoes-{ano}.xlsx'
    path_tabela = os.path.join(path, arquivo_excel)
    
    # Leia o arquivo Excel e adicione uma coluna 'ano' com o valor do ano
    df = pd.read_excel(path_tabela)
    df['ano'] = ano
    
    # Concatene o DataFrame atual com o DataFrame principal
    df_concatenado = pd.concat([df_concatenado, df], ignore_index=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
df_concatenado = df_concatenado.loc[:,ordem ]
df_concatenado
# Out:
#         ano id_votacao sigla_orgao  \
# 0      2003  140406-31        PLEN
# 1      2003  140406-31        PLEN
# 2      2003  140406-31        PLEN
# 3      2003  140406-31        PLEN
# 4      2003  140406-31        PLEN
# ...     ...        ...         ...
# 88364  2023  2351332-7        PLEN
# 88365  2023  2351332-7        PLEN
# 88366  2023  2351332-7        PLEN
# 88367  2023  2351332-7        PLEN
# 88368  2023  2351332-7        PLEN
#
#                                                                                                   descricao  \
# 0                                         Rejeitado o Requerimento. Sim: 3; Não: 258; Abst.: 0: Total: 261.
# 1                                         Rejeitado o Requerimento. Sim: 3; Não: 258; Abst.: 0: Total: 261.
# 2                                         Rejeitado o Requerimento. Sim: 3; Não: 258; Abst.: 0: Total: 261.
# ...

# %%
df_concatenado.rename(columns = {'idVotacao':'id_votacao',
'siglaOrgao':'sigla_orgao',
'descricao':'descricao',
'siglaBancada':'id_proposicao',
'orientacao':'orientacao'}, inplace = True)

# %%
for ano in [*range(2003, 2023)]:
    particao = output + f'\\orientacao_bancada_votacao\\ano={ano}\\'
    if not os.path.exists(particao):
      os.makedirs(particao)

# %%
for ano in [*range(2003, 2023)]:
    df_particao = df_concatenado[df_concatenado['ano'] == ano].copy() # O .copy não é necessário é apenas uma boa prática
    df_particao.drop(['ano'], axis=1, inplace=True) # É preciso excluir as colunas utilizadas para partição 
    particao = output + f'\\orientacao_bancada_votacao\\ano={ano}\\data.csv'
    df_particao.to_csv(particao, index=False, encoding='utf-8', na_rep='')

# %% [markdown]
# #### Voto Parlamentar

# %%
df_concatenado = pd.DataFrame()
path = r'C:\Users\User\Downloads\workspace\br_camera_deputados\input\voto_parlamentar'


# Loop pelos anos de 2003 a 2023
for ano in range(2001, 2024):
    # Crie o caminho para o arquivo Excel correspondente ao ano
    arquivo_excel = f'votacoesVotos-{ano}.xlsx'
    path_tabela = os.path.join(path, arquivo_excel)
    
    # Leia o arquivo Excel e adicione uma coluna 'ano' com o valor do ano
    df = pd.read_excel(path_tabela)
    df['ano'] = ano
    
    # Concatene o DataFrame atual com o DataFrame principal
    df_concatenado = pd.concat([df_concatenado, df], ignore_index=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
df_concatenado.rename(columns = {'idVotacao':'id_votacao',
'dataHoraVoto':'data_hora',
'voto':'voto',
'deputado_id':'id_deputado',
'deputado_nome':'nome',
'deputado_siglaPartido':'sigla_partido',
'deputado_siglaUf':'sigla_uf',
'deputado_idLegislatura':'id_legislatura',}, inplace =True)

# %%
ordem =[
'ano',
'id_votacao',
'data_hora',
'voto',
'id_deputado',
'nome',
'sigla_partido',
'sigla_uf',
'id_legislatura',]

# %%
df_concatenado = df_concatenado.loc[:,ordem]

# %%
for ano in [*range(2001, 2023)]:
    particao = output + f'\\voto_parlamentar\\ano={ano}\\'
    if not os.path.exists(particao):
      os.makedirs(particao)

# %%
for ano in [*range(2001, 2023)]:
    df_particao = df_concatenado[df_concatenado['ano'] == ano].copy() # O .copy não é necessário é apenas uma boa prática
    df_particao.drop(['ano'], axis=1, inplace=True) # É preciso excluir as colunas utilizadas para partição 
    particao = output + f'\\voto_parlamentar\\ano={ano}\\data.csv'
    df_particao.to_csv(particao, index=False, encoding='utf-8', na_rep='')

# %% [markdown]
# #### votocao_proposicao_afetada

# %%
df_concatenado = pd.DataFrame()
path = r'C:\Users\User\Downloads\workspace\br_camera_deputados\input\votocao_proposicao_afetada'


# Loop pelos anos de 2003 a 2023
for ano in anos:
    # Crie o caminho para o arquivo Excel correspondente ao ano
    arquivo_excel = f'votacoesProposicoes-{ano}.xlsx'
    path_tabela = os.path.join(path, arquivo_excel)
    
    # Leia o arquivo Excel e adicione uma coluna 'ano' com o valor do ano
    df = pd.read_excel(path_tabela)
    df['ano'] = ano
    
    # Concatene o DataFrame atual com o DataFrame principal
    df_concatenado = pd.concat([df_concatenado, df], ignore_index=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
anos =[
1974,
1980,
1984,
1988,
1989,
1990,
1991,
1992,
1993,
1994,
1995,
1996,
1997,
1998,
1999,
2000,
2001,
2002,
2003,
2004,
2005,
2006,
2007,
2008,
2009,
2010,
2011,
2012,
2013,
2014,
2015,
2016,
2017,
2018,
2019,
2020,
2021,
2022,
2023,]

# %%
df_concatenado.rename(columns ={'idVotacao':'id_votacao',
'data':'data',
'descricao':'descricao',
'proposicao_id':'id_proposicao',
'proposicao_ano':'ano_proposicao',
'proposicao_titulo':'titulo',
'proposicao_ementa':'ementa',
'proposicao_codTipo':'codigo_tipo',
'proposicao_siglaTipo':'sigla_tipo',
'proposicao_numero':'numero',},inplace = True)

# %%
ordem= ['ano',
'id_votacao',
'data',
'descricao',
'id_proposicao',
'ano_proposicao',
'titulo',
'ementa',
'codigo_tipo',
'sigla_tipo',
'numero',]

# %%
df_concatenado =df_concatenado.loc[:,ordem]

# %%
for ano in anos:
    particao = output + f'\\votocao_proposicao_afetada\\ano={ano}\\'
    if not os.path.exists(particao):
      os.makedirs(particao)

# %%
for ano in anos:
    df_particao = df_concatenado[df_concatenado['ano'] == ano].copy() # O .copy não é necessário é apenas uma boa prática
    df_particao.drop(['ano'], axis=1, inplace=True) # É preciso excluir as colunas utilizadas para partição 
    particao = output + f'\\votocao_proposicao_afetada\\ano={ano}\\data.csv'
    df_particao.to_csv(particao, index=False, encoding='utf-8', na_rep='')

# %% [markdown]
# ### votação objeto

# %%
df_concatenado = pd.DataFrame()
path = r'C:\Users\User\Downloads\workspace\br_camera_deputados\input\votacao_objeto'


# Loop pelos anos de 2003 a 2023
for ano in anos:
    # Crie o caminho para o arquivo Excel correspondente ao ano
    arquivo_excel = f'votacoesObjetos-{ano}.xlsx'
    path_tabela = os.path.join(path, arquivo_excel)
    
    # Leia o arquivo Excel e adicione uma coluna 'ano' com o valor do ano
    df = pd.read_excel(path_tabela)
    df['ano'] = ano
    
    # Concatene o DataFrame atual com o DataFrame principal
    df_concatenado = pd.concat([df_concatenado, df], ignore_index=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
anos =[
1935,
1946,
1947,
1948,
1952, 
1955,
1964,
1966,
1967,
1968,
1970,
1971,
1972,
1974,
1980,
1984,
1985,
1988,
1989,
1990,
1991,
1992,
1993,
1994,
1995,
1996,
1997,
1998,
1999,
2000,
2001,
2002,
2003,
2004,
2005,
2006,
2007,
2008,
2009,
2010,
2011,
2012,
2013,
2014,
2015,
2016,
2017,
2018,
2019,
2020,
2021,
2022,
2023,]

# %%
df_concatenado.rename(columns={'idVotacao':'id_votacao',
'data':'data',
'descricao':'descricao',
'proposicao_id':'id_proposicao',
'proposicao_ano':'ano_proposicao',
'proposicao_ementa':'ementa',
'proposicao_codTipo':'codigo_tipo',
'proposicao_siglaTipo':'sigla_tipo',
'proposicao_numero':'numero',
'proposicao_titulo':'titulo',}, inplace =True)

# %%
ordem= ['ano',
'id_votacao',
'data',
'descricao',
'id_proposicao',
'ano_proposicao',
'ementa',
'codigo_tipo',
'sigla_tipo',
'numero',
'titulo',]

# %%
for ano in anos:
    particao = output + f'\\votacao_objeto\\ano={ano}\\'
    if not os.path.exists(particao):
      os.makedirs(particao)

# %%
for ano in anos:
    df_particao = df_concatenado[df_concatenado['ano'] == ano].copy() # O .copy não é necessário é apenas uma boa prática
    df_particao.drop(['ano'], axis=1, inplace=True) # É preciso excluir as colunas utilizadas para partição 
    particao = output + f'\\votacao_objeto\\ano={ano}\\data.csv'
    df_particao.to_csv(particao, index=False, encoding='utf-8', na_rep='')

# %% [markdown]
# #### Votação microdados

# %%
df_concatenado = pd.DataFrame()
path = r'C:\Users\User\Downloads\workspace\br_camera_deputados\input\votacao_microdados'


# Loop pelos anos de 2003 a 2023
for ano in anos:
    # Crie o caminho para o arquivo Excel correspondente ao ano
    arquivo_excel = f'votacoes-{ano}.xlsx'
    path_tabela = os.path.join(path, arquivo_excel)
    
    # Leia o arquivo Excel e adicione uma coluna 'ano' com o valor do ano
    df = pd.read_excel(path_tabela)
    df['ano'] = ano
    
    # Concatene o DataFrame atual com o DataFrame principal
    df_concatenado = pd.concat([df_concatenado, df], ignore_index=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
anos =[
1935,
1946,
1947,
1948,
1952, 
1955,
1964,
1966,
1967,
1968,
1970,
1971,
1972,
1974,
1980,
1984,
1985,
1988,
1989,
1990,
1991,
1992,
1993,
1994,
1995,
1996,
1997,
1998,
1999,
2000,
2001,
2002,
2003,
2004,
2005,
2006,
2007,
2008,
2009,
2010,
2011,
2012,
2013,
2014,
2015,
2016,
2017,
2018,
2019,
2020,
2021,
2022,
2023,]

# %%
df_concatenado.rename(columns={'id':'id_votacao',
'data':'data',
'dataHoraRegistro':'horario',
'idOrgao':'id_orgao',
'siglaOrgao':'sigla_orgao',
'idEvento':'id_evento',
'aprovacao':'aprovacao',
'votosSim':'voto_sim',
'votosNao':'voto_nao',
'votosOutros':'voto_outro',
'descricao':'descricao',
'ultimaAberturaVotacao_dataHoraRegistro':'data_hora_ultima_votacao',
'ultimaAberturaVotacao_descricao':'descricao_ultima_votacao',
'ultimaApresentacaoProposicao_dataHoraRegistro':'data_hora_ultima_proposicao',
'ultimaApresentacaoProposicao_descricao':'descricao_ultima_proposicao',
'ultimaApresentacaoProposicao_idProposicao':'id_ultima_proposicao',}, inplace = True)

# %%
ordem = ['ano',
'id_votacao',
'data',
'horario',
'id_orgao',
'sigla_orgao',
'id_evento',
'aprovacao',
'voto_sim',
'voto_nao',
'voto_outro',
'descricao',
'data_hora_ultima_votacao',
'descricao_ultima_votacao',
'data_hora_ultima_proposicao',
'descricao_ultima_proposicao',
'id_ultima_proposicao',]

# %%
 df_concatenado = df_concatenado.loc[:,ordem]

# %%
for ano in anos:
    particao = output + f'\\votacao_microdados\\ano={ano}\\'
    if not os.path.exists(particao):
      os.makedirs(particao)

# %%
for ano in anos:
    df_particao = df_concatenado[df_concatenado['ano'] == ano].copy() # O .copy não é necessário é apenas uma boa prática
    df_particao.drop(['ano'], axis=1, inplace=True) # É preciso excluir as colunas utilizadas para partição 
    particao = output + f'\\votacao_microdados\\ano={ano}\\data.csv'
    df_particao.to_csv(particao, index=False, encoding='utf-8', na_rep='')
