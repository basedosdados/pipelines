# %%
URL = "https://siconfi.tesouro.gov.br/siconfi/pages/public/consulta_finbra/finbra_list.jsf"

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 62
#      58         driver.quit()
#      61 # Uncomment to run inspection:
# ---> 62 inspect_page_structure()
#
# Cell In[1], line 4, in inspect_page_structure()
#       2 def inspect_page_structure():
#       3     """Open the page and print useful information about its structure."""
# ----> 4     driver = setup_driver(headless=False)
#       5     try:
#       6         driver.get(URL)
#
# NameError: name 'setup_driver' is not defined
