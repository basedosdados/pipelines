# %%
import numpy as np
import pandas as pd
pns_2019 = r'pns2019.csv'
pns_2019_output = r'microdados_2019.csv'
pns_2013 = r'PNS_2013.csv'
pns_2013_output = r'microdados_2013.csv'

#https://www.pns.icict.fiocruz.br/bases-de-dados/

def replace_values_2013(value):
    if pd.isna(value):
        return 'não informado'
    if value == '1':
        return 'sim'
    elif value == '2':
        return 'não'
    elif value == '':
        return 'não aplicável'
    else:
        return 'não informado' if value.strip() == '' else value
def replace_values_2019(value):
    if pd.isna(value):
        return 'não informado'
    if value == '1':
        return 'sim'
    elif value == '2':
        return 'não'
    elif value == '9':
        return 'ignorado'
    elif value == '':
        return 'não aplicável'
    else:
        return 'não informado' if value.strip() == '' else value
def trim_left_zeros(value):
    if pd.isna(value):
        return ''
    if value == '0':
        return '0'
    else:
        return value.lstrip('0')
    


vectorized_replace_values_2013 = np.vectorize(replace_values_2013)
vectorized_replace_values_2019 = np.vectorize(replace_values_2019)
vectorized_trim_left_zeros = np.vectorize(trim_left_zeros)

# %%
#Definir listas de colunas que devem ser tratadas

replace_col_list_2019 = [
                        "A02201",
                        "C01001",
                        "C013",
                        "C015",
                        "C016",
                        "C017",
                        "D001",
                        "D007",
                        "D008",
                        "D01303",
                        "D014",
                        "E001",
                        "E002",
                        "E003",
                        "E01403",
                        "E022",
                        "E026",
                        "E02601",
                        "E02801",
                        "E02802",
                        "E02803",
                        "E02804",
                        "E02805",
                        "E02806",
                        "E030",
                        "E03101",
                        "E03102",
                        "E03103",
                        "E03104",
                        "E03105",
                        "E03106",
                        "E03107",
                        "E03108",
                        "E032",
                        "G033",
                        "G034",
                        "G035",
                        "G036",
                        "G038",
                        "G039",
                        "G040",
                        "G041",
                        "G042",
                        "G044",
                        "G048",
                        "G049",
                        "G050",
                        "G051",
                        "G052",
                        "G053",
                        "G054",
                        "G055",
                        "G05801",
                        "G059",
                        "G060",
                        "G061",
                        "G062",
                        "G063",
                        "G064",
                        "G065",
                        "G066",
                        "G067",
                        "G068",
                        "G072",
                        "G073",
                        "G074",
                        "G075",
                        "G076",
                        "G077",
                        "G084",
                        "I00101",
                        "I00102",
                        "I004",
                        "I00401",
                        "I00402",
                        "I00403",
                        "I00404",
                        "J002",
                        "J005",
                        "J007",
                        "J00801",
                        "J009",
                        "J021",
                        "J024",
                        "J025",
                        "J02901",
                        "J035",
                        "J037",
                        "J042",
                        "J046",
                        "K01901",
                        "K02001",
                        "K02102",
                        "K03401",
                        "K045",
                        "K046",
                        "K047",
                        "K050",
                        "K052",
                        "K05401",
                        "K05402",
                        "k055",
                        "K05601",
                        "K05602",
                        "L01701",
                        "L01702",
                        "L01703",
                        "L01704",
                        "L01705",
                        "L01706",
                        "L01707",
                        "L01708",
                        "L01709",
                        "L01710",
                        "L01711",
                        "L01712",
                        "L01713",
                        "L01714",
                        "L01715",
                        "L01716",
                        "L018",
                        "L019",
                        "L035",
                        "M00203",
                        "N004",
                        "N005",
                        "O019",
                        "O02001",
                        "P00601",
                        "Q121012",
                        "Q121013",
                        "Q121014",
                        "Q121015",
                        "Q121016",
                        "Q124",
                        "Q12501",
                        "Q12607",
                        "Q12608",
                        "Q12609",
                        "Q12610",
                        "Q128",
                        "Q132",
                        "R004",
                        "R008",
                        "R010",
                        "R014",
                        "R015",
                        "R019",
                        "R023",
                        "R026",
                        "R030",
                        "R032",
                        "R033",
                        "R034",
                        "R03601",
                        "R03602",
                        "R03603",
                        "R03604",
                        "R03605",
                        "R03606",
                        "R03607",
                        "R03608",
                        "R03609",
                        "R03610",
                        "R03611",
                        "S065",
                        "S068",
                        "S075",
                        "S076",
                        "S091",
                        "S109",
                        "S113",
                        "S114",
                        "S116",
                        "S119",
                        "S120",
                        "S121",
                        "S123",
                        "S124",
                        "S125",
                        "S126",
                        "S127",
                        "S128",
                        "S130",
                        "S131",
                        "S132",
                        "S134",
                        "S138",
                        "U00204",
                        "U00205",
                        "U00206",
                        "U00207",
                        "U00208",
                        "U02001",
                        "H002",
                        "H005",
                        "H006",
                        "H007",
                    ]

trim_left_col_list_2019 = [
    'V0022', 'A01001', 'A011', 'A01401', 'A01402', 'A018012',
       'A018014', 'A018016', 'A018018', 'A018020', 'A018022', 'A018024',
       'A018026', 'A018028', 'A02102', 'A02305', 'A02306', 'A02307',
       'A02308', 'A02401', 'A02402', 'C001', 'C00301', 'C00701', 'C00702',
       'C008', 'C01801', 'E010011', 'E010012', 'E010013', 'E019',
       'E024021', 'E02502', 'E02503', 'E033', 'VDF00102', 'I001021',
       'J003', 'J006', 'J012', 'J019', 'J038', 'J04001', 'J04002',
       'K04302', 'M00303', 'M00401', 'M00402', 'M005011', 'O00901',
       'O02101', 'P00103', 'P00104', 'P00403', 'P00404', 'P006', 'P00901',
       'P01101', 'P013', 'P015', 'P02001', 'P01601', 'P018', 'P02002',
       'P023', 'P02501', 'P02602', 'P02801', 'P029', 'P03202', 'P035',
       'P03701', 'P03702', 'P03905', 'P03906', 'P04101', 'P04102',
       'P04301', 'P04302', 'P04401', 'P04405', 'P04406', 'P053', 'P05402',
       'P05403', 'P05405', 'P05406', 'P05408', 'P05409', 'P05411',
       'P05412', 'P05414', 'P05415', 'P05417', 'P05418', 'P05421',
       'P05422', 'P05601', 'P05602', 'P05603', 'P05604', 'P05605',
       'P05801', 'P05802', 'P05901', 'P05902', 'P05903', 'P05904', 'Q003',
       'Q031', 'Q061', 'Q064', 'Q070', 'Q075', 'Q080', 'Q085', 'Q08901',
       'Q09301', 'Q111', 'Q11701', 'Q12201', 'Q125', 'Q133', 'R012',
       'R025', 'R027', 'S066', 'S06701', 'S06702', 'S06703', 'S06901',
       'S06902', 'S09901', 'S11001', 'S11801', 'U02303', 'U02403',
       'Z00101', 'Z00102', 'Z002', 'Z003', 'Z01401', 'Z01402', 'Y00101',
       'W00101', 'W00102', 'W00103', 'W00201', 'W00202', 'W00203',
       'VDC001', 'VDC003', 'VDF002', 'VDF003', 'VDL001',
]

replace_col_list_2013 = [
                        "J019",
                        "J020",
                        "J027",
                        "J036",
                        "J038",
                        "J04001",
                        "J04002",
                        "K053",
                        "K06001",
                        "K06002",
                        "K06003",
                        "K06101",
                        "K06102",
                        "L00201",
                        "L00202",
                        "L00203",
                        "L003",
                        "L01613",
                        "L01614",
                        "L01615",
                        "L01616",
                        "L01617",
                        "L01618",
                        "L01619",
                        "L01620",
                        "L01621",
                        "L01622",
                        "L01623",
                        "L01624",
                        "M01301",
                        "M01302",
                        "M01303",
                        "M014",
                        "M015",
                        "O00901",
                        "O011",
                        "O016",
                        "O01801",
                        "O01802",
                        "O02101",
                        "O034",
                        "O042",
                        "O046",
                        "P036",
                        "P063",
                        "Q012",
                        "Q021",
                        "Q024",
                        "Q033",
                        "Q040",
                        "Q049",
                        "Q052",
                        "Q095",
                        "Q102",
                        "Q108",
                        "Q137",
                        "R002",
                        "R009",
                        "R012",
                        "R016",
                        "R024",
                        "R025",
                        "R027",
                        "R040",
                        "R04101",
                        "R04201",
                        "R043",
                        "R044",
                        "R045",
                        "R046",
                        "R047",
                        "R048",
                        "R04901",
                        "R04902",
                        "S003",
                        "S004",
                        "S019",
                        "S026",
                        "S036",
                        "S038",
                        "S043",
                        "S044",
                        "S045",
                        "S050",
                        "U009",
                        "U010",
                        "U01701",
                        "U01702",
                        "U01801",
                        "U01802",
                        "U02301",
                        "U02401",
                        "X003",
                        "X005",
                        "X007",
                        "X01401",
                        "X01402",
                        "X01501",
                        "X01502",
                        "X024",
                        "VDC001",
                        "VDC002",
                        "VDF002",
                        "VDF003",
                    ]

# %%
#Tratamento br_ms_pns.microdados_2019

df = pd.read_csv(pns_2019, sep = ',', dtype = str)

for column in replace_col_list_2019:
    print(f'making column {column}')
    df[column] = vectorized_replace_values_2019(df[column])
    
    
for column in trim_left_col_list_2019:
    print(f'making column {column}')
    df[column] = vectorized_trim_left_zeros(df[column])
    
    
    
df.to_csv(pns_2019_output, encoding='utf-8', na_rep='', sep=',', index=False)

# %%
#Tratamento br_ms_pns.microdados_2013

df = pd.read_csv(pns_2013, sep = ';', dtype = str)

for column in replace_col_list_2013:
    print(f'making column {column}')
    df[column] = vectorized_replace_values_2013(df[column])
    
    
for column in trim_left_col_list_2013:
    print(f'making column {column}')
    df[column] = vectorized_trim_left_zeros(df[column])
    
    
    
df.to_csv(pns_2013_output, encoding='utf-8', na_rep='', sep=',', index=False)
# Out:
# making column A007
# making column A012
# making column A01801
# making column A01803
# making column A01805
# making column A01807
# making column A01809
# making column A01811
# making column A01815
# making column A01817
# making column A019
# making column A021
# making column A022
# making column D001
# making column D002
# making column D005
# making column D007
# making column D008
# making column D011
# making column D012
# making column D014
# making column E001
# making column E002
# making column E003
# making column E004
# making column E005
# making column E007
# making column E008
# making column G005
# making column G010
# making column G018
# making column G024
# making column G02501
# making column G02502
# making column G02503
# making column G027
# making column I003
# making column I004
# making column I008
# making column J005
# making column J008
# making column J017
# making column J021
# making column J024
# making column J025
# making column J035
# ...
